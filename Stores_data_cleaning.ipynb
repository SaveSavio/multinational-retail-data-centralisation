# %% [markdown]
# # Data Cleaning Template
#
# This notebook was created to take advantage of the Jupyter visualizations for cleaning data.<br>
# The commands defined in this notebook will be then used in the **multinational_retail_data_project**

# %% [markdown]
#  Performs the cleaning of the user data for
#
# 1. NULL values
# 2. errors with dates
# 3. incorrectly typed values
# 4. rows filled with the wrong information

# %%
# need to mount Google Drive to be able to load data from it
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import pandas and the RDS table that needs cleaning
file_name = 'stores_data.csv'
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/001. Data Science/005. Ai Core/014. Multinational Data Centralization Project/" + file_name)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'address', 'longitude', 'lat', 'locality',
#        'store_code', 'staff_numbers', 'opening_date', 'store_type', 'latitude',
#        'country_code', 'continent'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  index                                            address  \
# 0           0      0                                                NaN
# 1           1      1  Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...
# 2           2      2        Heckerstraße 4/5\n50491 Säckingen, Landshut
# 3           3      3  5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury
# 4           4      4  Studio 6\nStephen landing\nSouth Simon\nB77 2W...
#
#   longitude  lat      locality    store_code staff_numbers opening_date  \
# 0       NaN  NaN           NaN  WEB-1388012W           325   2010-06-12
# 1  51.62907  NaN  High Wycombe   HI-9B97EE4E            34   1996-10-25
# 2  48.52961  NaN      Landshut   LA-0772C7B9            92   2013-04-12
# 3     51.26  NaN      Westbury   WE-1DE82CEE            69   2014-01-02
# 4   53.0233  NaN        Belper   BE-18074576            35   2019-09-09
#
#     store_type  latitude country_code continent
# 0   Web Portal       NaN           GB    Europe
# 1        Local  -0.74934           GB    Europe
# 2  Super Store  12.16179           DE    Europe
# 3  Super Store   -2.1875           GB    Europe
# 4        Local  -1.48119           GB    Europe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     451 non-null    int64
#  1   index          451 non-null    int64
#  2   address        447 non-null    object
#  3   longitude      447 non-null    object
#  4   lat            7 non-null      object
#  5   locality       447 non-null    object
#  6   store_code     448 non-null    object
#  7   staff_numbers  448 non-null    object
#  8   opening_date   448 non-null    object
#  9   store_type     448 non-null    object
#  10  latitude       447 non-null    object
#  11  country_code   448 non-null    object
#  12  continent      448 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 45.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# index              0
# address            4
# longitude          4
# lat              444
# locality           4
# store_code         3
# staff_numbers      3
# opening_date       3
# store_type         3
# latitude           4
# country_code       3
# continent          3
# dtype: int64

# %%
df[df['lat'].notnull()]
# Out:
#      Unnamed: 0  index     address   longitude         lat    locality  \
# 63           63     63  6FWDZHD7PW  1ZVU03X2P6  13KJZ890JH  9IBH8Y4Z0S
# 172         172    172  UBCIFQLSNY  Q1TJY8H1ZH  2XE1OWOC23  1T6B406CI8
# 231         231    231  RC99UKMZB2  2YBZ1440V6  OXVE5QR07O  6LVWPU1G64
# 333         333    333  X349GIDWKU  O7NF1FZ74Y  VKA5I8H32X  RX9TCP2RGB
# 381         381    381  ZBGB54ID4H  SKO4NMRNNF  LACCWDI0SB  CQMHKI78BX
# 414         414    414  XTUAV57DP4  ID819KG3X5  A3O5CBWAMD  RY6K0AUE7F
# 447         447    447  K0ODETRLS3  K8CXLZDP07  UXMWDMX1LC  3VHFDNP8ET
#
#      store_code staff_numbers opening_date  store_type    latitude  \
# 63   NRQKZWJ9OZ    BIP8K8JJW2   ZCXWWKF45G  QP74AHEQT0  1CJ5OAU4BR
# 172  QIUU9SVP51    SKBXAXF5G5   7AHXLXIUEF  O0QJIRC943  3ZR3F89D97
# 231  Y8J0Z2W8O9    2429OB3LMM   0OLAK2I6NS  50IB01SFAZ  L13EQEQODP
# 333  ISEE8A57FE    74BY7HSB6P   A3PMVM800J  0RSNUU3DF5  J3BPB68Z1J
# 381  T0R2CQBDUS    GT1FO6YGD4   GMMB02LA9V  B4KVQB3P5Y  AJHOMDOHZ4
# 414  TUOKF5HAAQ    FRTGHAA34B   13PIY8GD1H  X0FE7E2EOG  AE7EEW4HSS
# 447  9D4LK7X4LZ    D23PCWSM6S   36IIMAQD58  NN04B3F6UQ  JZP8MIJTPZ
#
#     country_code   continent
# 63    YELVM536YT  QMAVR5H3LD
# 172   FP8DLXQVGH  LU3E036ZD9
# 231   HMHIFNLOBN  5586JCLARW
# 333   F3AO8V2LHU  GFJQ2AAEQ8
# 381   OH20I92LX3  SLQBD982C0
# 414   OYVW925ZL8  XQ953VS0FG
# 447   B3EH2ZGQAV  1WZB1TE1HL

# %%
df[df['address'].isnull()]
# Out:
#      Unnamed: 0  index address longitude  lat locality    store_code  \
# 0             0      0     NaN       NaN  NaN      NaN  WEB-1388012W
# 217         217    217     NaN       NaN  NaN      NaN           NaN
# 405         405    405     NaN       NaN  NaN      NaN           NaN
# 437         437    437     NaN       NaN  NaN      NaN           NaN
#
#     staff_numbers opening_date  store_type latitude country_code continent
# 0             325   2010-06-12  Web Portal      NaN           GB    Europe
# 217           NaN          NaN         NaN      NaN          NaN       NaN
# 405           NaN          NaN         NaN      NaN          NaN       NaN
# 437           NaN          NaN         NaN      NaN          NaN       NaN

# %%
df[df['locality'].isnull()]
# Out:
#      Unnamed: 0  index address longitude  lat locality    store_code  \
# 0             0      0     NaN       NaN  NaN      NaN  WEB-1388012W
# 217         217    217     NaN       NaN  NaN      NaN           NaN
# 405         405    405     NaN       NaN  NaN      NaN           NaN
# 437         437    437     NaN       NaN  NaN      NaN           NaN
#
#     staff_numbers opening_date  store_type latitude country_code continent
# 0             325   2010-06-12  Web Portal      NaN           GB    Europe
# 217           NaN          NaN         NaN      NaN          NaN       NaN
# 405           NaN          NaN         NaN      NaN          NaN       NaN
# 437           NaN          NaN         NaN      NaN          NaN       NaN

# %% [markdown]
# ## To does
# 1. Drop the stores with "lat" column not null. Those 7 row bring wrong information.
# 2. There are additional 3 rows that are filled with NaN and should be removed.
# 3. We must pay attention to the index 0 which represents the online store. That must be kept.

# %%
#df = df.drop(['Unnamed: 0', 'index'], axis = 1)
# I found later that Unnamed: 0 is not created when importing from VSCode. So the command should be only
df = df.drop(['index'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-8891d49c5b27> in <cell line: 3>()
#       1 df = df.drop(['Unnamed: 0', 'index'], axis = 1)
#       2 # I found later that Unnamed: 0 is not created when importing from VSCode. So the command should be only
# ----> 3 df = df.drop(['index'], axis = 1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
# drop any row with all NaN
df = df[df.notna().any(axis=1)]

# %%
df  = df[~df['lat'].notnull()]

# %%
df.isna().sum()
# Out:
# address            1
# longitude          1
# lat              441
# locality           1
# store_code         0
# staff_numbers      0
# opening_date       0
# store_type         0
# latitude           1
# country_code       0
# continent          0
# dtype: int64

# %%
# for the online store, I prefer removing the "NaN" with the string "online", so to avoid any problem at later stage
# df.loc[0].fillna("online", inplace = True)

# %% [markdown]
# Remove the incorrect dates

# %%
df['latitude'].astype(float).describe()
# Out:
# count    440.000000
# mean      -4.729191
# std       25.361348
# min     -122.391680
# 25%       -2.523980
# 50%       -0.749340
# 75%        8.466143
# max       13.321270
# Name: latitude, dtype: float64

# %%
df[df['latitude'].astype(float) < 0]
# Out:
#                                                address longitude  lat  \
# 1    Flat 72W\nSally isle\nEast Deantown\nE7B 8EB, ...  51.62907  NaN
# 3    5 Harrison tunnel\nSouth Lydia\nWC9 2BE, Westbury     51.26  NaN
# 4    Studio 6\nStephen landing\nSouth Simon\nB77 2W...   53.0233  NaN
# 5    Flat 92u\nChristian harbors\nPort Charlotte\nN...  53.38333  NaN
# 6    7 Gillian rue\nWest Robertside\nPH4 8NY, Ruthe...  55.82885  NaN
# ..                                                 ...       ...  ...
# 441  Flat 89\nRicky trafficway\nEast Alicechester\n...  53.00974  NaN
# 442  Flat 98H\nStephanie squares\nPort Lindsey\nSA6...  57.14369  NaN
# 443  Studio 31\nGraeme via\nNorth Amanda\nB30 4PJ, ...   53.0233  NaN
# 445  Flat 7\nStephanie lake\nMorrisside\nHP8 8LH, C...  50.76306  NaN
# 448  Studio 8\nMoss mall\nWest Linda\nM0E 6XR, High...  51.62907  NaN
#
#               locality   store_code staff_numbers opening_date   store_type  \
# 1         High Wycombe  HI-9B97EE4E            34   1996-10-25        Local
# 3             Westbury  WE-1DE82CEE            69   2014-01-02  Super Store
# 4               Belper  BE-18074576            35   2019-09-09        Local
# 5         Gainsborough  GA-CAD01AC2            36   1995-05-15        Local
# 6           Rutherglen  RU-C603E990            92   2001-01-04  Super Store
# ..                 ...          ...           ...          ...          ...
# 441  Rhosllanerchrugog  RH-80D609C9            23   2017-01-14        Local
# 442           Aberdeen  AB-D5ABF437            22   2020-12-15        Local
# 443             Belper  BE-B069E157            40   2019-10-30        Local
# 445              Cowes  CO-473A9FBB            94   2008-06-08  Super Store
# 448       High Wycombe  HI-EEA7AE62            33   1998-05-14        Local
#
#      latitude country_code continent
# 1    -0.74934           GB    Europe
# 3     -2.1875           GB    Europe
# 4    -1.48119           GB    Europe
# 5    -0.76667           GB    Europe
# 6    -4.21376           GB    Europe
# ..        ...          ...       ...
# 441  -3.05814           GB    Europe
# 442  -2.09814           GB    Europe
# 443  -1.48119           GB    Europe
# 445  -1.29772           GB    Europe
# 448  -0.74934           GB    Europe
#
# [261 rows x 11 columns]

# %%
df['country_code'].value_counts()
# all the stores are in the northern emisphere and I already checked some latitudes are not correct
df['latitude'] = df['latitude'].astype(float).abs()

# %%
df['longitude'].astype(float).describe()
# Out:
# count    440.000000
# mean      50.930031
# std        4.496084
# min       26.684510
# 25%       50.238050
# 50%       51.427080
# 75%       53.191460
# max       57.479080
# Name: longitude, dtype: float64

# %% [markdown]
# DOB now contains zero errors

# %%
# not sure it is really worth modifying that
import datetime
df['opening_date'] = pd.to_datetime(df['opening_date'], infer_datetime_format=True, errors = 'coerce')

# %%
df['opening_date'].isnull().sum()
# Out:
# 0

# %%
staff_mask = df['staff_numbers'].apply(pd.to_numeric, errors='coerce').isnull()
df[staff_mask == True]
# Out:
#                                                address longitude  lat  \
# 31   Flat 69\nSuzanne walk\nEast Michelle\nE80 8HS,...  52.68333  NaN
# 179         Girschnerweg 163\n93597 Angermünde, Dahlem   52.4581  NaN
# 248  7430 Howe Extensions Suite 299\nKellyside, WA ...  39.71734  NaN
# 341  Studio 8\nLydia groves\nNorth Hilarymouth\nIV4...  50.79205  NaN
# 375  Salzstraße 1/9\n74209 Bad Freienwalde, Charlot...  52.53048  NaN
#
#                 locality   store_code  staff_numbers opening_date  \
# 31          East Dereham  EA-24B31935            NaN   2012-11-09
# 179               Dahlem  DA-ACC520AE            NaN   1994-03-07
# 248         Sicklerville  SI-C489938D            NaN   1994-02-28
# 341             Southsea  SO-B5B9CB3B            NaN   2018-05-08
# 375  Charlottenburg-Nord  CH-99475026            NaN   1995-03-05
#
#       store_type  latitude country_code continent
# 31        Outlet   0.93333           GB    Europe
# 179        Local  13.28702           DE    Europe
# 248       Outlet  74.96933           US   America
# 341  Super Store   1.08593           GB    Europe
# 375        Local  13.29371           DE    Europe

# %%
import numpy as np
mean_staff = np.mean(df['staff_numbers'])
df.loc[staff_mask == True, 'staff_numbers'] = mean_staff

# %%
np.mean(df['staff_numbers'])
# Out:
# 46.9954128440367

# %%
df[staff_mask == True]
# Out:
#                                                address longitude  lat  \
# 31   Flat 69\nSuzanne walk\nEast Michelle\nE80 8HS,...  52.68333  NaN
# 179         Girschnerweg 163\n93597 Angermünde, Dahlem   52.4581  NaN
# 248  7430 Howe Extensions Suite 299\nKellyside, WA ...  39.71734  NaN
# 341  Studio 8\nLydia groves\nNorth Hilarymouth\nIV4...  50.79205  NaN
# 375  Salzstraße 1/9\n74209 Bad Freienwalde, Charlot...  52.53048  NaN
#
#                 locality   store_code  staff_numbers opening_date  \
# 31          East Dereham  EA-24B31935      46.995413   2012-11-09
# 179               Dahlem  DA-ACC520AE      46.995413   1994-03-07
# 248         Sicklerville  SI-C489938D      46.995413   1994-02-28
# 341             Southsea  SO-B5B9CB3B      46.995413   2018-05-08
# 375  Charlottenburg-Nord  CH-99475026      46.995413   1995-03-05
#
#       store_type  latitude country_code continent
# 31        Outlet   0.93333           GB    Europe
# 179        Local  13.28702           DE    Europe
# 248       Outlet  74.96933           US   America
# 341  Super Store   1.08593           GB    Europe
# 375        Local  13.29371           DE    Europe

# %% [markdown]
# # Summary

# %%
df = df.drop(['index'], axis = 1)
df = df[df.notna().any(axis=1)]
df  = df[~df['lat'].notnull()]
df['latitude'] = df['latitude'].astype(float).abs()
import datetime
df['opening_date'] = pd.to_datetime(df['opening_date'], infer_datetime_format=True, errors = 'coerce')
staff_mask = df['staff_numbers'].apply(pd.to_numeric, errors='coerce').isnull()
import numpy as np
mean_staff = np.mean(df['staff_numbers'])
df.loc[staff_mask == True, 'staff_numbers'] = mean_staff
