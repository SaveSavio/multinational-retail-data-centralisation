# %% [markdown]
# # RDS server user data cleaning
# This notebook was created to take advantage of the Jupyter visualizations when cleaning the data.<br>
# The commands defined in this notebook will be then used in the **clean_user_data** method of the **DataCleaning** class.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import pandas and the RDS table that needs cleaning
import pandas as pd
df = pd.read_csv("RDS_table.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-eaeb606f2d71> in <cell line: 3>()
#       1 # import pandas and the RDS table that needs cleaning
#       2 import pandas as pd
# ----> 3 df = pd.read_csv("RDS_table.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head()
#df.columns
# Out:
#    Unnamed: 0  level_0  index                             date_uuid  \
# 0           0        0      0  9476f17e-5d6a-4117-874d-9cdb38ca1fa6
# 1           1        1      1  0423a395-a04d-4e4a-bd0f-d237cbd5a295
# 2           2        2      2  65187294-bb16-4519-adc0-787bbe423970
# 3           3        3      3  579e21f7-13cb-436b-83ad-33687a4eb337
# 4           4        4      4  00ab86c3-2039-4674-b9c1-adbcbbf525bd
#
#   first_name last_name                             user_uuid  \
# 0        NaN       NaN  93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8
# 1        NaN       NaN  8fe96c3a-d62d-4eb5-b313-cf12d9126a49
# 2        NaN       NaN  fc461df4-b919-48b2-909e-55c95a03fe6b
# 3        NaN       NaN  6104719f-ef14-4b09-bf04-fb0c4620acb0
# 4        NaN       NaN  9523a6d3-b2dd-4670-a51a-36aebc89f579
#
#         card_number    store_code product_code   1  product_quantity
# 0    30060773296197   BL-8387506C  R7-3126933h NaN                 3
# ...

# %%
# plot the "Unnamed" column
df["Unnamed: 0"].sample(100)
# Out:
# 6679        6679
# 55971      55971
# 21401      21401
# 99474      99474
# 117079    117079
# 68566      68566
# 15330      15330
# 92479      92479
# 91874      91874
# 108895    108895
# 2845        2845
# 54203      54203
# 51942      51942
# 91594      91594
# 56816      56816
# 9159        9159
# 61496      61496
# 896          896
# 90106      90106
# 92649      92649
# 88366      88366
# 91533      91533
# 69093      69093
# 118158    118158
# 72944      72944
# 119250    119250
# 2808        2808
# 83111      83111
# 58813      58813
# 78988      78988
# 111506    111506
# 25689      25689
# 107988    107988
# 47793      47793
# 30426      30426
# 49354      49354
# 84213      84213
# 70298      70298
# 57186      57186
# 40600      40600
# 1454        1454
# 38364      38364
# 94063      94063
# 115355    115355
# 63046      63046
# 43874      43874
# 95764      95764
# 47856      47856
# 43723      43723
# 62945      62945
# 3489        3489
# 25691      25691
# ...

# %%
# plot the "level_0" column
df["level_0"].head(10000)
# Out:
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#         ...
# 9995    10010
# 9996    10011
# 9997    10012
# 9998    10013
# 9999    10014
# Name: level_0, Length: 10000, dtype: int64

# %% [markdown]
# It is unclear what the level_0 column does

# %% [markdown]
# This column does not add any information respect to the index. We can remove it.

# %% [markdown]
# ## To does
# 1) drop the "Unnamed: 0" column
