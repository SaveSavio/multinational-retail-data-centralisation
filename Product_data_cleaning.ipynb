# %% [markdown]
# # Product Data Cleaning
#
# Step 2:
# Create a method in the DataCleaning class called convert_product_weights this will take the products DataFrame as an argument and return the products DataFrame.
# If you check the weight column in the DataFrame the weights all have different units.
# Convert them all to a decimal value representing their weight in kg. Use a 1:1 ratio of ml to g as a rough estimate for the rows containing ml.
# Develop the method to clean up the weight column and remove all excess characters then represent the weights as a float.

# %% [markdown]
#  Performs the cleaning of the user data for
#
# 1. NULL values
# 2. errors with dates
# 3. incorrectly typed values
# 4. rows filled with the wrong information

# %%
# need to mount Google Drive to be able to load data from it
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import pandas and the RDS table that needs cleaning
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/001. Data Science/005. Ai Core/014. Multinational Data Centralization Project/products.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'product_name', 'product_price', 'weight', 'category',
#        'EAN', 'date_added', 'uuid', 'removed', 'product_code'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                                 product_name product_price  \
# 0           0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1           1          Tiffany's World Day Out At The Park        £12.99
# 2           2          Tiffany's World Pups Picnic Playset         £7.00
# 3           3     Tiffany's World Wildlife Park Adventures        £12.99
# 4           4                      Cosatto Cosy Dolls Pram        £30.00
#
#    weight        category            EAN  date_added  \
# 0   1.6kg  toys-and-games  7425710935115  2005-12-02
# 1  0.48kg  toys-and-games   487128731892  2006-01-09
# 2    590g  toys-and-games  1945816904649  1997-03-29
# 3    540g  toys-and-games  1569790890899  2013-03-20
# 4  1.91kg  toys-and-games  7142740213920  2007-12-23
#
#                                    uuid          removed product_code
# 0  83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1  712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2  b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3  d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4  7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1853 entries, 0 to 1852
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1853 non-null   int64
#  1   product_name   1849 non-null   object
#  2   product_price  1849 non-null   object
#  3   weight         1849 non-null   object
#  4   category       1849 non-null   object
#  5   EAN            1849 non-null   object
#  6   date_added     1849 non-null   object
#  7   uuid           1849 non-null   object
#  8   removed        1849 non-null   object
#  9   product_code   1849 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 144.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# product_name     4
# product_price    4
# weight           4
# category         4
# EAN              4
# date_added       4
# uuid             4
# removed          4
# product_code     4
# dtype: int64

# %%
df[df['product_name'].isnull()]
# Out:
#       Unnamed: 0 product_name product_price weight category  EAN date_added  \
# 266          266          NaN           NaN    NaN      NaN  NaN        NaN
# 788          788          NaN           NaN    NaN      NaN  NaN        NaN
# 794          794          NaN           NaN    NaN      NaN  NaN        NaN
# 1660        1660          NaN           NaN    NaN      NaN  NaN        NaN
#
#      uuid removed product_code
# 266   NaN     NaN          NaN
# 788   NaN     NaN          NaN
# 794   NaN     NaN          NaN
# 1660  NaN     NaN          NaN

# %%
df = df[df['product_name'].notnull()]

# %% [markdown]
# The NaN can be removed immediately

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# product_name     0
# product_price    0
# weight           0
# category         0
# EAN              0
# date_added       0
# uuid             0
# removed          0
# product_code     0
# dtype: int64

# %% [markdown]
# Step 2:
# Create a method in the DataCleaning class called convert_product_weights this will take the products DataFrame as an argument and return the products DataFrame.
# If you check the weight column in the DataFrame the weights all have different units.
# Convert them all to a decimal value representing their weight in kg. Use a 1:1 ratio of ml to g as a rough estimate for the rows containing ml.
# Develop the method to clean up the weight column and remove all excess characters then represent the weights as a float.

# %%
#df.rename(columns={"weight": "weight_to_be_cleaned"}, inplace = True)

# %% [markdown]
# # Need doing
# 1. there is mistype "avaliable"
# 2. need to remove the pound
# 3. convert stuff to float

# %%
# create a column that contains the units of the weight column
df['units'] = df['weight'].str.replace('\d+', '', regex=True).str.replace('.', '', regex=True)
df['units'].value_counts()
# Out:
# kg           954
# g            853
#  x g          28
# ml             9
# GONZJTL        1
# ZZTDGUZVU      1
# MXRYSHX        1
# g              1
# oz             1
# Name: units, dtype: int64

# %%
# I give it a try anyway I cannot apply this method because of the columns like 12 x 80g
# for those columns I have to separate the grams from the number of items then multiply them together
# df['weight'].str.replace('[a-zA-Z]', '')

# %%
df['units'].value_counts()
# Out:
# kg           954
# g            853
#  x g          28
# ml             9
# GONZJTL        1
# ZZTDGUZVU      1
# MXRYSHX        1
# g              1
# oz             1
# Name: units, dtype: int64

# %%
list_of_values = ['GONZJTL', 'ZZTDGUZVU', 'MXRYSHX']
df[df['units'].str.contains('|'.join(list_of_values))]
# Out:
#       Unnamed: 0 product_name product_price      weight    category  \
# 751          751   VLPCU81M30    XCD69KUI0K  9GO9NZ5JTL  S1YB74MLMJ
# 1133        1133   9SX4G65YUX    N9D2BZQX63  Z8ZTDGUZVU  C3NCA2CL35
# 1400        1400   LB3D71C025    ODPMASE7V7  MX180RYSHX  WVPMHZP59U
#
#              EAN  date_added        uuid     removed product_code      units
# 751   OO7KH8P79I  CCAVRB79VV  7QB0Z9EW1G  T3QRRH7SRP   SDAV678FVD    GONZJTL
# 1133  E8EOGWOY8S  09KREHTMWL  CP8XYQVGGU  BPSADIOQOK  BSDTR67VD90  ZZTDGUZVU
# 1400  BHPF2JTNKQ  PEPWA0NCVH  VIBLHHVPMN  H5N71TV8AY   OPSD21HN67    MXRYSHX

# %% [markdown]
# Also these lines can be removed as they are all wrong

# %%
df = df[~df['units'].str.contains('|'.join(list_of_values))]

# %%
# I create the column of weight_kg

# %%
import numpy as np
df['weight_kg'] = np.nan

# %%
# this method allows to separate the number of items from the single item weight.
# This is the first thing I have to sort
df['weight_kg'] =  df[df['units'].str.contains('x')]['weight'].str.extract(r'(\d+)\s*x\s*(\d+)', expand=False)[0].astype(float) * df[df['units'].str.contains('x')]['weight'].str.extract(r'(\d+)\s*x\s*(\d+)', expand=False)[1].astype(float) * 0.001

# %%
# df['weight_kg'].value_counts()

# %%
# execute this row, it works perfectly!
df[df['weight_kg'].notnull()]

# %%
# this line just converts the columns with 'units' equal to kg into a float and assign it to the column 'weight clean"
mask = df['units'] == 'kg'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('kg', '').astype(float)

# %%
# this line converts the columns with 'units' equal to g into a float, then converts to kg, and assign it to the column 'weight clean"
mask = df['units'] == 'g'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('g', '').astype(float) * 0.001

# %%
# this line converts the columns with 'units' equal to ml into a float, then converts to kg, and assign it to the column 'weight clean"

mask = df['units'] == 'ml'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('ml', '').astype(float) * 0.001

# %%
# this line converts the columns with 'units' equal to oz into a float, then converts to kg, and assign it to the column 'weight clean"
mask = df['units'] == 'oz'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('oz', '').astype(float) * 0.0283495

# %%
df[df['units'] == 'g']
# Out:
#       Unnamed: 0                               product_name product_price  \
# 2              2        Tiffany's World Pups Picnic Playset         £7.00
# 3              3   Tiffany's World Wildlife Park Adventures        £12.99
# 11            11       Disney Encanto Isabela's Garden Room        £24.99
# 12            12        Disney Encanto Antonio's Tree House        £24.99
# 145          145                       Ultimate Glamour Kit        £12.99
# ...          ...                                        ...           ...
# 1847        1847                   RAC 12V Wet & Dry Vacuum        £18.00
# 1848        1848  Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849  Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                   RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851  Goodmans Qi Autosense In Car Phone Holder        £15.00
#
#      weight        category            EAN  date_added  \
# 2      590g  toys-and-games  1945816904649  1997-03-29
# 3      540g  toys-and-games  1569790890899  2013-03-20
# 11     1.2g  toys-and-games  9644535434254  2019-08-14
# 12     1.2g  toys-and-games  2421335285067  2019-04-13
# 145    726g  toys-and-games  7985188210850  2016-10-02
# ...     ...             ...            ...         ...
# 1847   820g             diy  4847679041653  2003-03-09
# 1848   125g             diy  8185827751600  2020-08-28
# 1849   134g             diy  9769724533935  2012-05-20
# 1850   820g             diy  3113855860327  1993-11-28
# 1851   125g             diy  9195087467400  2016-09-20
#
#                                       uuid          removed product_code  \
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 11    e36989b3-7371-40ea-80b8-c23ba1a6869f  Still_avaliable  S6-3678717g
# 12    d3ed56bc-533e-42fe-839a-ba880bda5714  Still_avaliable  Z2-0851042W
# 145   410e261a-c9ce-4390-995e-abefda80db5d  Still_avaliable   v2-903142f
# ...                                    ...              ...          ...
# 1847  4b3b3ff4-f32f-4602-a679-239b399b679f  Still_avaliable   s1-001714d
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
#
#      units  weight_clean
# 2        g        0.5900
# 3        g        0.5400
# 11       g        0.0012
# 12       g        0.0012
# 145      g        0.7260
# ...    ...           ...
# 1847     g        0.8200
# 1848     g        0.1250
# 1849     g        0.1340
# 1850     g        0.8200
# 1851     g        0.1250
#
# [853 rows x 12 columns]

# %%
df = df.drop(['weight', 'units'], axis = 1)

# %%
df
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#             category            EAN  date_added  \
# 0     toys-and-games  7425710935115  2005-12-02
# 1     toys-and-games   487128731892  2006-01-09
# 2     toys-and-games  1945816904649  1997-03-29
# 3     toys-and-games  1569790890899  2013-03-20
# 4     toys-and-games  7142740213920  2007-12-23
# ...              ...            ...         ...
# 1848             diy  8185827751600  2020-08-28
# 1849             diy  9769724533935  2012-05-20
# 1850             diy  3113855860327  1993-11-28
# 1851             diy  9195087467400  2016-09-20
# 1852             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code  \
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
#       weight_clean
# 0            1.600
# 1            0.480
# 2            0.590
# 3            0.540
# 4            1.910
# ...            ...
# 1848         0.125
# 1849         0.134
# 1850         0.820
# 1851         0.125
# 1852         9.400
#
# [1846 rows x 10 columns]

# %%
df['product_price'] = df['product_price'].str.replace('£', '').astype(float)

# %%
df
# Out:
#       Unnamed: 0                                 product_name  product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin          39.99
# 1              1          Tiffany's World Day Out At The Park          12.99
# 2              2          Tiffany's World Pups Picnic Playset           7.00
# 3              3     Tiffany's World Wildlife Park Adventures          12.99
# 4              4                      Cosatto Cosy Dolls Pram          30.00
# ...          ...                                          ...            ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder          15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand          15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum          18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder          15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m          69.00
#
#             category            EAN  date_added  \
# 0     toys-and-games  7425710935115  2005-12-02
# 1     toys-and-games   487128731892  2006-01-09
# 2     toys-and-games  1945816904649  1997-03-29
# 3     toys-and-games  1569790890899  2013-03-20
# 4     toys-and-games  7142740213920  2007-12-23
# ...              ...            ...         ...
# 1848             diy  8185827751600  2020-08-28
# 1849             diy  9769724533935  2012-05-20
# 1850             diy  3113855860327  1993-11-28
# 1851             diy  9195087467400  2016-09-20
# 1852             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code  \
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
#       weight_clean
# 0            1.600
# 1            0.480
# 2            0.590
# 3            0.540
# 4            1.910
# ...            ...
# 1848         0.125
# 1849         0.134
# 1850         0.820
# 1851         0.125
# 1852         9.400
#
# [1846 rows x 10 columns]

# %%
# clean the date column and transform it into a datetime object
import datetime
df['date_added'] = pd.to_datetime(df['date_added'], infer_datetime_format=True, errors = 'coerce')

# %%
df['removed'].value_counts()
# Out:
# Still_avaliable    1752
# Removed              94
# Name: removed, dtype: int64

# %%
df['removed'] = df['removed'].str.replace('Still_avaliable', 'Still_available')

# %%
df['category'].value_counts()
# Out:
# homeware              1138
# toys-and-games         257
# food-and-drink         250
# pets                    93
# sports-and-leisure      40
# health-and-beauty       40
# diy                     28
# Name: category, dtype: int64

# %% [markdown]
# It seems there are
#
# *   kg
# *   g and also (N x g, N being the number of units)
# *   oz
# *   ml
# *   some errors...

# %% [markdown]
# # Summary

# %%
# remove rows with all null entries
df = df[df['product_name'].notnull()]
# create a column that contains the units of the weight column
df['units'] = df['weight'].str.replace('\d+', '', regex=True).str.replace('.', '', regex=True)
# analysis the 'units' column, create a list of values that make no sense
list_of_values = ['GONZJTL', 'ZZTDGUZVU', 'MXRYSHX']
# remove the rows which 'units' column contains any item in the list_of_values
df = df[~df['units'].str.contains('|'.join(list_of_values))]
# create an empty column that will contain the weight in kg
import numpy as np
df['weight_kg'] = np.nan

# process the items such as "12 x 100g" by splitting those into a df with two colums, the index[0] containing the number of items
# ("12") and the index[1] the weight of each item (100g). The weight is then cleaned from the unit.
# the two are multiplied and then converted to kg
df['weight_kg'] =  df[df['units'].str.contains('x')]['weight'].str.extract(r'(\d+)\s*x\s*(\d+)', expand=False)[0].astype(float) * df[df['units'].str.contains('x')]['weight'].str.extract(r'(\d+)\s*x\s*(\d+)', expand=False)[1].astype(float) * 0.001

# this line just converts the columns with 'units' equal to kg into a float and assign it to the column 'weight clean"
mask = df['units'] == 'kg'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('kg', '').astype(float)

# this line converts the columns with 'units' equal to g into a float, then converts to kg, and assign it to the column 'weight clean"
mask = df['units'] == 'g'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('g', '').astype(float) * 0.001

# this line converts the columns with 'units' equal to ml into a float, then converts to kg, and assign it to the column 'weight clean"

mask = df['units'] == 'ml'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('ml', '').astype(float) * 0.001

# this line converts the columns with 'units' equal to oz into a float, then converts to kg, and assign it to the column 'weight clean"
mask = df['units'] == 'oz'
masked_df = df[mask]
df.loc[mask, 'weight_kg'] = df.loc[mask, 'weight'].str.replace('oz', '').astype(float) * 0.0283495

# drop two columns made redundant by the cleaning process
df = df.drop(['weight', 'units'], axis = 1)

# clean the price column from the £ sign
df['product_price'] = df['product_price'].str.replace('£', '').astype(float)

# clean the date column and transform it into a datetime object
import datetime
df['date_added'] = pd.to_datetime(df['date_added'], infer_datetime_format=True, errors = 'coerce')

# sort the mispelled entries in the 'removed' column
df['removed'] = df['removed'].str.replace('Still_avaliable', 'Still_available')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-c4ec299cf039> in <cell line: 1>()
# ----> 1 df = df.drop(['index'], axis = 1)
#       2 df = df[df.notna().any(axis=1)]
#       3 df  = df[~df['lat'].notnull()]
#       4 df = df.drop('lat', inplace = True)
#       5 df['latitude'] = df['latitude'].astype(float).abs()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"
